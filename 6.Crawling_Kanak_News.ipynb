# %% [markdown]
# <a href="https://colab.research.google.com/github/biranchi2018/My-WebScraping-Examples/blob/master/6.Crawling_Kanak_News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## WebScraping Kanak News

# %%
# !pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 245kB 2.9MB/s
# ...
#      |████████████████████████████████| 2.7MB 8.2MB/s
# ...
#      |████████████████████████████████| 235kB 26.0MB/s
# ...
#      |████████████████████████████████| 61kB 7.0MB/s
# ...
#      |████████████████████████████████| 3.1MB 24.4MB/s
# ...
#      |████████████████████████████████| 3.2MB 45.6MB/s
# ...
#      |████████████████████████████████| 61kB 7.8MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp36-none-any.whl size=11515 sha256=3d348530f1eee8beea0bcd5b7e2c24e57ebd32586659b48a7b8b61bdf653dd18
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# ...
#   Created wheel for protego: filename=Protego-0.1.16-cp36-none-any.whl size=7765 sha256=028401d48732eddc9d3461c4a3aa5233acac2f5a405b97c66a326034c7bc8fa4
#   Stored in directory: /root/.cache/pip/wheels/51/01/d1/4a2286a976dccd025ba679acacfe37320540df0f2283ecab12
# Successfully built PyDispatcher protego
# ...

# %%
import scrapy

from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors.lxmlhtml import LxmlLinkExtractor
from scrapy.linkextractors import LinkExtractor
#from scrapy.contrib.linkextractors.sgml import SgmlLinkExtractor
from scrapy.http.request import Request

# %%
class mySpider(CrawlSpider):
	name = 'mySpider'
	start_urls = ['https://kanaknews.com']
	allowed_domains = ['kanaknews.com']

	rules = (Rule(
    	LinkExtractor(
        allow_domains = ('kanaknews.com'),
        attrs = ('href'),
        tags = ('a'),
        deny = (),
        deny_extensions = (),
        unique = True,
    ),
    callback = 'parse', follow = True),)

	def parse(self, response):
		extractor = LinkExtractor(allow_domains='kanaknews.com')
		links = extractor.extract_links(response)
		for link in links:
			yield Request(link.url, self.parse)
		for title in response.xpath("//div[@class='post-content']"):
			yield {'title': title.xpath("//div[@class='post-content']/p/text()").extract()}

# %%
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess()
process.crawl(mySpider)
process.start()

# %%
# Out:
# 2020-06-21 15:48:16 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: scrapybot)
# 2020-06-21 15:48:16 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Apr 18 2020, 01:56:04) - [GCC 8.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic
# 2020-06-21 15:48:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-06-21 15:48:16 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-06-21 15:48:16 [scrapy.extensions.telnet] INFO: Telnet Password: f59ce95fe2573d52
# 2020-06-21 15:48:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %%
# Usage
# !scrapy crawl mySpider -s download_maxsize=0 -o my-output.json
# Out:
# Scrapy 2.1.0 - no active project
#
# Unknown command: crawl
#
# Use "scrapy" to see available commands

# %% [markdown]
# ## Sample Example

# %%
import scrapy


class Kanak_News_Spider(scrapy.Spider):
    name = "news"
    start_urls = [
        'https://kanaknews.com/'
    ]

    def parse(self, response):
        page = response.url.split("/")[-2]
        filename = 'kanak_news-%s.html' % page
        with open(filename, 'wb') as f:
            f.write(response.body)
